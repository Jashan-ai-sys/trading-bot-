# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

end = datetime.today() - timedelta(days=1)   # yesterday
start = end - timedelta(days=2000)            # last 1 year

data = yf.download("SBIN.NS", start=start, end=end, interval="1d")
data.reset_index(inplace=True)
print(data.shape)
print(data.head())
# Out:
# C:\Users\V\AppData\Local\Temp\ipykernel_2656\3268103730.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("SBIN.NS", start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# (1358, 6)
# Price        Date       Close        High         Low        Open    Volume
# Ticker                SBIN.NS     SBIN.NS     SBIN.NS     SBIN.NS   SBIN.NS
# 0      2020-05-14  154.970245  158.476571  154.555026  157.738395  48136531
# 1      2020-05-15  153.540039  155.247070  151.971424  154.970253  35495540
# 2      2020-05-18  143.297882  153.540027  143.021064  153.540027  77349435
# 3      2020-05-19  140.991104  145.650826  140.622009  145.327869  71522334
# 4      2020-05-20  141.544708  143.251739  139.468596  141.175627  66168767
