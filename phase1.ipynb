# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

end = datetime.today() - timedelta(days=1)   # yesterday
start = end - timedelta(days=365)            # last 1 year

data = yf.download("SBIN.NS", start=start, end=end, interval="1d")
data.reset_index(inplace=True)
print(data.shape)
print(data.head())
# Out:
# C:\Users\WIN11\AppData\Local\Temp\ipykernel_15032\2218978361.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("SBIN.NS", start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# (249, 6)
# Price        Date       Close        High         Low        Open    Volume
# Ticker                SBIN.NS     SBIN.NS     SBIN.NS     SBIN.NS   SBIN.NS
# 0      2024-10-28  776.459045  788.124826  768.126362  768.371441  13757251
# 1      2024-10-29  816.308899  818.416542  774.939564  780.331301  28274791
# 2      2024-10-30  806.260620  816.602938  804.888154  811.701360  15977682
# 3      2024-10-31  804.054932  811.701382  797.535808  803.858857  13402324
# 4      2024-11-01  805.035278  809.348632  802.780564  806.211669   1637141
